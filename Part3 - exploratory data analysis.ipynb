# %% [markdown]
# # Data Analysis tutorial: Part 3 - Exploratory Data Analysis

# %% [markdown]
# ### Descriptive Statistics

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('imports3.csv')
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3              122.0  alfa-romero        std          two
# 1            3              122.0  alfa-romero        std          two
# 2            1              122.0  alfa-romero        std          two
# 3            2              164.0         audi        std         four
# 4            2              164.0         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1               95.0        volvo        std         four
# 197         -1               95.0        volvo      turbo         four
# 198         -1               95.0        volvo        std         four
# 199         -1               95.0        volvo      turbo         four
# 200         -1               95.0        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0    convertible          rwd           front        88.6  0.413433  ...
# 1    convertible          rwd           front        88.6  0.413433  ...
# 2      hatchback          rwd           front        94.5  0.449254  ...
# 3          sedan          fwd           front        99.8  0.529851  ...
# 4          sedan          4wd           front        99.4  0.529851  ...
# ..           ...          ...             ...         ...       ...  ...
# 196        sedan          rwd           front       109.1  0.711940  ...
# 197        sedan          rwd           front       109.1  0.711940  ...
# 198        sedan          rwd           front       109.1  0.711940  ...
# 199        sedan          rwd           front       109.1  0.711940  ...
# 200        sedan          rwd           front       109.1  0.711940  ...
#
#      stroke  compression-ratio  horsepower peak-rpm city-L/100km  highway-mpg  \
# 0      2.68                9.0       111.0   5000.0    11.190476           27
# 1      2.68                9.0       111.0   5000.0    11.190476           27
# 2      3.47                9.0       154.0   5000.0    12.368421           26
# 3      3.40               10.0       102.0   5500.0     9.791667           30
# 4      3.40                8.0       115.0   5500.0    13.055556           22
# ..      ...                ...         ...      ...          ...          ...
# 196    3.15                9.5       114.0   5400.0    10.217391           28
# 197    3.15                8.7       160.0   5300.0    12.368421           25
# 198    2.87                8.8       134.0   5500.0    13.055556           23
# 199    3.40               23.0       106.0   4800.0     9.038462           27
# 200    3.15                9.5       114.0   5400.0    12.368421           25
#
#      price  price-binned  fuel-type_diesel  fuel-type_gas
# 0    13495           Low                 0              1
# 1    16500           Low                 0              1
# 2    16500           Low                 0              1
# 3    13950           Low                 0              1
# 4    17450           Low                 0              1
# ..     ...           ...               ...            ...
# 196  16845           Low                 0              1
# 197  19045        Medium                 0              1
# 198  21485        Medium                 0              1
# 199  22470        Medium                 1              0
# 200  22625        Medium                 0              1
#
# [201 rows x 28 columns]

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.494045    0.915126
# std      1.254802           31.99625    6.066366    0.183913    0.029187
# min     -2.000000           65.00000   86.600000    0.000000    0.837500
# 25%      0.000000          101.00000   94.500000    0.383582    0.890278
# 50%      1.000000          122.00000   97.000000    0.479104    0.909722
# 75%      2.000000          137.00000  102.400000    0.632836    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean     0.899108  2555.666667   126.875622    3.330711    3.256904
# std      0.040933   517.296727    41.546834    0.268072    0.316048
# min      0.799331  1488.000000    61.000000    2.540000    2.070000
# 25%      0.869565  2169.000000    98.000000    3.150000    3.110000
# 50%      0.904682  2414.000000   120.000000    3.310000    3.290000
# 75%      0.928094  2926.000000   141.000000    3.580000    3.410000
# max      1.000000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm  city-L/100km  highway-mpg  \
# count         201.000000  201.000000   201.000000    201.000000   201.000000
# mean           10.164279  103.396985  5117.587940      9.944145    30.686567
# std             4.004965   37.365602   478.113178      2.534599     6.815150
# min             7.000000   48.000000  4150.000000      4.795918    16.000000
# 25%             8.600000   70.000000  4800.000000      7.833333    25.000000
# 50%             9.000000   95.000000  5117.587940      9.791667    30.000000
# 75%             9.400000  116.000000  5500.000000     12.368421    34.000000
# max            23.000000  262.000000  6600.000000     18.076923    54.000000
#
#               price  fuel-type_diesel  fuel-type_gas
# count    201.000000        201.000000     201.000000
# mean   13207.129353          0.099502       0.900498
# std     7947.066342          0.300083       0.300083
# min     5118.000000          0.000000       0.000000
# 25%     7775.000000          0.000000       1.000000
# 50%    10295.000000          0.000000       1.000000
# 75%    16500.000000          0.000000       1.000000
# max    45400.000000          1.000000       1.000000

# %%
df["drive-wheels"].value_counts().to_frame()
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
import seaborn as sns

# %%
sns.boxplot(x= "drive-wheels", y= "price", data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
import matplotlib.pyplot as plt

# %%
y = df["price"]
x = df["engine-size"]
plt.scatter(x,y)
plt.title("Engine size VS Price")
plt.xlabel("Engine size")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ### groupby

# %%
df_test = df[['drive-wheels', 'body-style', 'price']]
df_grp = df_test.groupby(['drive-wheels', 'body-style'], as_index=False).mean()
df_grp
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
df_pivot = df_grp.pivot(index = 'drive-wheels', columns = 'body-style')
df_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
plt.pcolor(df_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Correlation
# ### Positive correlation

# %%
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53295.631027126554)

# %% [markdown]
# ### Negative correlation

# %%
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48173.06800806253)

# %% [markdown]
# ### Weak correlation

# %%
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
import scipy.stats as st

# %%
pearson_coef, p_value = st.pearsonr(df['horsepower'], df['price'])
pearson_coef, p_value
# Out:
# (0.8096811975632285, 6.058444649710621e-48)
